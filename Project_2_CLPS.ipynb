# %% [markdown]
# <a href="https://colab.research.google.com/github/desmondg19/CLPSProject2/blob/main/Project_2_CLPS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#test

# %%
https://github.com/USCOVIDpolicy/COVID-19-US-State-Policy-Database.git

# %%
from google.colab import drive
from os.path import join
ROOT= '/content/drive'
print(ROOT)
drive.mount(ROOT4/1AY0e-g6smIiObKqWtJ4tUnScqOOwqFmmHqgNo-CW1-LcM8CrTPH925wmbnI)
# Out:
# /content/drive
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-4c6d2b7e-24cc-4428-937a-d223d357de8f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4c6d2b7e-24cc-4428-937a-d223d357de8f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving COVID-19 US state policy database 3_29_2021.xlsx to COVID-19 US state policy database 3_29_2021.xlsx

# %%
import io
df=pd.read_excel(io.BytesIO(uploaded['COVID-19 US state policy database 3_29_2021.xlsx']))
df
# Out:
#                    STATE  ...                                SMALLBUSMINWAGE
# 0                  State  ...  Different Minimum Wage for Smaller Businesses
# 1               category  ...                                   minimum_wage
# 2                   type  ...                                      attribute
# 3                   unit  ...                                           flag
# 4                Alabama  ...                                              0
# 5                 Alaska  ...                                              0
# 6                Arizona  ...                                              0
# 7               Arkansas  ...                                              1
# 8             California  ...                                              1
# 9               Colorado  ...                                              1
# 10           Connecticut  ...                                              0
# ...
